# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score

# %%
import pandas as pd
df = pd.read_csv("CarPrice_Assignment.csv",index_col=0)
df = df.dropna()
Car = pd.DataFrame(df)

# %%
Car.head()
# Out:
#         symboling                   CarName fueltype aspiration doornumber  \
# car_ID
# 1               3        alfa-romero giulia      gas        std        two
# 2               3       alfa-romero stelvio      gas        std        two
# 3               1  alfa-romero Quadrifoglio      gas        std        two
# 4               2               audi 100 ls      gas        std       four
# 5               2                audi 100ls      gas        std       four
#
#             carbody drivewheel enginelocation  wheelbase  carlength  ...  \
# car_ID                                                               ...
# 1       convertible        rwd          front       88.6      168.8  ...
# 2       convertible        rwd          front       88.6      168.8  ...
# 3         hatchback        rwd          front       94.5      171.2  ...
# 4             sedan        fwd          front       99.8      176.6  ...
# ...

# %%
Car.corr()["price"].sort_values()
# Out:
# highwaympg         -0.697599
# citympg            -0.685751
# peakrpm            -0.085267
# symboling          -0.079978
# compressionratio    0.067984
# stroke              0.079443
# carheight           0.119336
# boreratio           0.553173
# wheelbase           0.577816
# carlength           0.682920
# carwidth            0.759325
# horsepower          0.808139
# curbweight          0.835305
# enginesize          0.874145
# price               1.000000
# Name: price, dtype: float64

# %%
X = Car["horsepower"].values.reshape(-1,1)
Y = Car["price"].values.reshape(-1,1)

plt.scatter(X,Y)
plt.xlabel("horsepower")
plt.ylabel("price");

# %%
from sklearn.model_selection import train_test_split
X_train , X_test, Y_train, Y_test = train_test_split(X,Y, test_size = 0.3)




reg = LinearRegression().fit(X_train, Y_train )


y_train_hat = reg.predict(X_train)
y_test_hat = reg.predict(X_test)

# %%
plt.scatter(X_train, Y_train,label = "train")
plt.scatter(X_test, Y_test,label = "test")
plt.xlabel("horsepower")
plt.ylabel("price");
plt.legend();

# %%
plt.scatter(X_train, Y_train)
plt.scatter(X_test, Y_test)
X_plot = np.linspace(50,300).reshape(-1,1)
Y_plot = reg.predict(X_plot)
#Gráfica del modelo
plt.plot(X_plot,Y_plot, color = "red", label = "Modelo")
plt.xlabel("horsepower")
plt.ylabel("price");
plt.legend();

# %%
print("Entrenamiento : ",r2_score(Y_train,y_train_hat))
print("Prueba : ",r2_score(Y_test,y_test_hat))
# Out:
# Entrenamiento :  0.6387817570202541
# Prueba :  0.6890938401582197

# %%
import matplotlib.pyplot as plt
X = Car["enginesize"].values.reshape(-1,1)
Y = Car["price"].values.reshape(-1,1)
plt.scatter(X,Y)
plt.xlabel("enginesize")
plt.ylabel("price");

# %%
X_train , X_test, Y_train, Y_test = train_test_split(X,Y, test_size = 0.3)

from sklearn.linear_model import LinearRegression
reg = LinearRegression().fit(X_train, Y_train )


y_train_hat = reg.predict(X_train)
y_test_hat = reg.predict(X_test)

# %%
plt.scatter(X_train, Y_train,label = "train")
plt.scatter(X_test, Y_test,label = "test")
plt.xlabel("enginesize")
plt.ylabel("price");
plt.legend();

# %%
import numpy as np
#X_plot = np.linspace(50,300).reshape(-1,1)
#Y_plot = reg.predict(X_plot)
#plt.plot(X_plot,Y_plot, color = "red", label = "Modelo")

plt.scatter(X_train, Y_train,label = "train")
plt.scatter(X_test, Y_test,label = "test")

X_prediction = np.array([275])
X_prediction = X_prediction.reshape(-1,1)
Y_prediction = reg.predict(X_prediction)
plt.scatter(X_prediction, Y_prediction,label = "prediction")

plt.xlabel("enginesize")
plt.ylabel("price");
plt.legend();

# %%
import numpy as np
X_plot = np.linspace(50,300).reshape(-1,1)
Y_plot = reg.predict(X_plot)
plt.plot(X_plot,Y_plot, color = "red", label = "Modelo")

# %%
from sklearn.metrics import r2_score
print("Entrenamiento : ",r2_score(Y_train,y_train_hat))
print("Prueba : ",r2_score(Y_test,y_test_hat))
# Out:
# Entrenamiento :  0.7703906381874728
# Prueba :  0.7453931295784229

# %%
print(reg.intercept_)
print(reg.coef_)
# Out:
# [-7950.70550002]
# [[166.06797529]]

# %%
X_prueba = np.array([275])
X_prueba = X_prueba.reshape(-1,1)
Y_prueba = reg.predict(X_prueba)
print(Y_prueba)
# Out:
# [[37717.98770348]]

# %%
X = Car["curbweight"].values.reshape(-1,1)
Y = Car["price"].values.reshape(-1,1)

plt.scatter(X,Y)
plt.xlabel("curbweight")
plt.ylabel("price");
